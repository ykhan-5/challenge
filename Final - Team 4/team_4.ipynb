# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import requests
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Load the CSV data
# Load the first CSV file
data1 = pd.read_csv('data_well.csv')

# Load the second CSV file
data2 = pd.read_csv('data_well2.csv')

data3 = pd.read_csv('data_well3.csv')

# Combine the two DataFrames
data = pd.concat([data1, data2, data3], ignore_index=True)

# Create the 'previous_failure' column and drop rows with missing values
data['previous_failure'] = data['failure'].shift(1)
data = data.dropna(subset=['previous_failure'])

# Features and target
X = data.drop(['failure', 'sessionID', 'score', 'turn', 'previous_failure', 'team', 'Cuttings', 'Precipitation','MUD_Density_Rating', 'Permeability_Rating', 'Rotary_Speed', 'Rotary_Torque'], axis=1)
y = data['failure']

# Specify categorical and numerical features
categorical_features = [
 'Casing Integrity'
]
numerical_features = X.columns.difference(categorical_features)


preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ])


class_weights = {False: 1, True: 1.8}

# Create a pipeline with preprocessing and SVC
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', SVC(class_weight=class_weights))
    # ('classifier', KNeighborsClassifier())
    # ('classifier', LogisticRegression(class_weight=class_weights))
])

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Train the model
pipeline.fit(X_train, y_train)

# Predict on test data
y_pred = pipeline.predict(X_test)



# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("SVC model accuracy (in %):", accuracy * 100)
# print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# SVC model accuracy (in %): 78.20738137082601
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.78      1.00      0.88       445
#         True       0.00      0.00      0.00       124
#
#     accuracy                           0.78       569
#    macro avg       0.39      0.50      0.44       569
# weighted avg       0.61      0.78      0.69       569
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Program Files\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
X_columns = [
    'Bit_Temperature',  'Depth_Temperature',
    'Depth_of_Bit', 'MUD_Circulation', 'MUD_Density', 
    'Permeability',  'Porosity', 'Casing Integrity',
    'Pressure',  'Weight_on_Bit'
]

def update_class_weights_and_retrain(pipeline, X_train, y_train, iteration):
    # Increase weight for 'True' class every X iterations
    weight_increment = (iteration // 500) * 1.05
    class_weights = {False: 1, True: 1.7 + weight_increment}

    # Create a new pipeline with updated class weights
    updated_pipeline = Pipeline(steps=[
        ('preprocessor', preprocessor),
        # ('classifier', SVC(class_weight=class_weights))
        ('classifier', LogisticRegression(class_weight=class_weights))
    ])

    # Retrain the model
    updated_pipeline.fit(X_train, y_train)
    return updated_pipeline


# Function to make decision based on new data
def make_decision(new_data, pipeline):

    # Convert new data to DataFrame and ensure the columns are in the correct order
    new_data_df = pd.DataFrame([new_data])[X_columns]
    
    # Predict using the model
    prediction = pipeline.predict(new_data_df)

    print(prediction[0])
    
    # Return decision based on prediction
    return "Repair" if prediction[0] else "Drill"  # Model predicts failure or success

# Session management and API interaction
session_id = None

try:
    # Start the well and get the session ID
    response = requests.get("http://10.68.195.110:8000/well/start/4")
    response.raise_for_status()
    data = response.json()
    session_id = data.get('sessionID')

    print("Sessionid ; ", session_id)

    if not session_id:
        raise ValueError("Session ID not found in the response")

    print(f"Started well with session ID: {session_id}")

    conditions = data['conditions']
    new_data = {
        'Bit_Temperature': conditions['Bit_Temperature'],
        'Casing Integrity': conditions['Casing Integrity'],
        # 'Cuttings': conditions['Cuttings'],
        'Depth_Temperature': conditions['Depth_Temperature'],
        'Depth_of_Bit': conditions['Depth_of_Bit'],
        'MUD_Circulation': conditions['MUD_Circulation'],
        'MUD_Density': conditions['MUD_Density'],
        # 'MUD_Density_Rating': conditions['MUD_Density_Rating'],
        'Permeability': conditions['Permeability'],
        # 'Permeability_Rating': conditions['Permeability_Rating'],
        'Porosity': conditions['Porosity'],
        # 'Precipitation': conditions['Precipitation'],
        'Pressure': conditions['Pressure'],
        # 'Rotary_Speed': conditions['Rotary_Speed'],
        # 'Rotary_Torque': conditions['Rotary_Torque'],
        'Weight_on_Bit': conditions['Weight_on_Bit'],
    }

    # Initialize the count
    count = 0

    while count < 950:
        try:
            
            if count % 500 == 0 and count != 0:
                print(f"Updating class weights and retraining model at iteration {count}")
                pipeline = update_class_weights_and_retrain(pipeline, X_train, y_train, count)


            # print(data['failure'])
            #Make a decision based on new data
            if not data or data['failure'] == True:
                decision = "Repair"
            else:
                decision = make_decision(new_data, pipeline)
            
            # Call the appropriate endpoint based on the decision
            if decision == "Drill":
                drill_url = f"http://10.68.195.110:8000/well/drill/{session_id}"
                print(f"Requesting URL: {drill_url}")
                try:
                    response = requests.get(drill_url, timeout=3)
                    response.raise_for_status()
                    data = response.json()
                except requests.Timeout as e:
                    print(f"Timeout occurred: {e}. Trying fallback URL.")
                    try:
                        fallback_url = f"http://10.68.195.110:8000/well/current/{session_id}"
                        response = requests.get(fallback_url, timeout=3)
                        response.raise_for_status()
                        data = response.json()
                    except requests.RequestException as fallback_e:
                        print(f"Fallback request failed: {fallback_e}.")
                        data = None
                except requests.RequestException as e:
                    print(f"Request failed: {e}.")
                    data = None

            elif decision == "Repair":
                repair_url = f"http://10.68.195.110:8000/well/repair/{session_id}"
                print(f"Requesting URL: {repair_url}")
                try:
                    response = requests.get(repair_url, timeout=3)
                    response.raise_for_status()
                    data = response.json()
                except requests.Timeout as e:
                    print(f"Timeout occurred: {e}. Trying fallback URL.")
                    try:
                        fallback_url = f"http://10.68.195.110:8000/well/current/{session_id}"
                        response = requests.get(fallback_url, timeout=3)
                        response.raise_for_status()
                        data = response.json()
                    except requests.RequestException as fallback_e:
                        print(f"Fallback request failed: {fallback_e}.")
                        data = None
                except requests.RequestException as e:
                    print(f"Request failed: {e}.")
                    data = None

            # Extract new conditions and update new_data
            if data:
                conditions = data['conditions']
                new_data = {
                    'Bit_Temperature': conditions['Bit_Temperature'],
                    'Casing Integrity': conditions['Casing Integrity'],
                    # 'Cuttings': conditions['Cuttings'],
                    'Depth_Temperature': conditions['Depth_Temperature'],
                    'Depth_of_Bit': conditions['Depth_of_Bit'],
                    'MUD_Circulation': conditions['MUD_Circulation'],
                    'MUD_Density': conditions['MUD_Density'],
                    # 'MUD_Density_Rating': conditions['MUD_Density_Rating'],
                    'Permeability': conditions['Permeability'],
                    # 'Permeability_Rating': conditions['Permeability_Rating'],
                    'Porosity': conditions['Porosity'],
                    # 'Precipitation': conditions['Precipitation'],
                    'Pressure': conditions['Pressure'],
                    # 'Rotary_Speed': conditions['Rotary_Speed'],
                    # 'Rotary_Torque': conditions['Rotary_Torque'],
                    'Weight_on_Bit': conditions['Weight_on_Bit'],
                }
                score = data.get('score', 'N/A')
                turn = data.get('turn', 'N/A')
                print(f"Decision based on new data: {decision}, Score is: {score} Turn is: {turn}")

            # Increment the count
            count += 1

        except requests.RequestException as e:
            print(f"Error during API call: {e}")

finally:
    if session_id:
        try:
            # End the well process using the session ID
            end_url = f"http://10.68.195.110:8000/well/end/{session_id}"
            print(f"Ending URL: {end_url}")
            end_response = requests.get(end_url)
            end_response.raise_for_status()
            print(f"Ended well with session ID: {session_id}")
        except requests.RequestException as e:
            print(f"Error during ending the well: {e}")
# Out:
# Sessionid ;  g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Started well with session ID: g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: 1 Turn is: 1
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: 2 Turn is: 2
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: 3 Turn is: 3
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: 4 Turn is: 4
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: 5 Turn is: 5
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -5 Turn is: 6
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -8 Turn is: 7
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -7 Turn is: 8
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -6 Turn is: 9
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -5 Turn is: 10
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -4 Turn is: 11
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -3 Turn is: 12
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -13 Turn is: 13
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -16 Turn is: 14
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -15 Turn is: 15
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -14 Turn is: 16
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -13 Turn is: 17
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -12 Turn is: 18
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -22 Turn is: 19
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -25 Turn is: 20
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Request failed: HTTPConnectionPool(host='10.68.195.110', port=8000): Read timed out..
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -27 Turn is: 22
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -26 Turn is: 23
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -25 Turn is: 24
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -24 Turn is: 25
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -23 Turn is: 26
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -22 Turn is: 27
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -32 Turn is: 28
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -35 Turn is: 29
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -34 Turn is: 30
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -33 Turn is: 31
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -32 Turn is: 32
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -31 Turn is: 33
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -30 Turn is: 34
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -40 Turn is: 35
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -43 Turn is: 36
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -42 Turn is: 37
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -41 Turn is: 38
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -40 Turn is: 39
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -39 Turn is: 40
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -38 Turn is: 41
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -37 Turn is: 42
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -36 Turn is: 43
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -35 Turn is: 44
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -34 Turn is: 45
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -33 Turn is: 46
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -32 Turn is: 47
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -42 Turn is: 48
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -45 Turn is: 49
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -44 Turn is: 50
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -43 Turn is: 51
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -42 Turn is: 52
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -41 Turn is: 53
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -51 Turn is: 54
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -54 Turn is: 55
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -53 Turn is: 56
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -52 Turn is: 57
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -51 Turn is: 58
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -50 Turn is: 59
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -60 Turn is: 60
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -63 Turn is: 61
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -62 Turn is: 62
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -61 Turn is: 63
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -60 Turn is: 64
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -59 Turn is: 65
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -69 Turn is: 66
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -72 Turn is: 67
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -71 Turn is: 68
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -81 Turn is: 69
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -84 Turn is: 70
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -83 Turn is: 71
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -82 Turn is: 72
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -81 Turn is: 73
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -80 Turn is: 74
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -79 Turn is: 75
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -89 Turn is: 76
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -92 Turn is: 77
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -91 Turn is: 78
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -90 Turn is: 79
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -89 Turn is: 80
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -99 Turn is: 81
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -102 Turn is: 82
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -101 Turn is: 83
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -100 Turn is: 84
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -99 Turn is: 85
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -98 Turn is: 86
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -97 Turn is: 87
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -96 Turn is: 88
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -95 Turn is: 89
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -105 Turn is: 90
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -108 Turn is: 91
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -107 Turn is: 92
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -106 Turn is: 93
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -105 Turn is: 94
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -104 Turn is: 95
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -103 Turn is: 96
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -102 Turn is: 97
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -112 Turn is: 98
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -115 Turn is: 99
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -114 Turn is: 100
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -113 Turn is: 101
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -112 Turn is: 102
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -111 Turn is: 103
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -110 Turn is: 104
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -109 Turn is: 105
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -108 Turn is: 106
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -107 Turn is: 107
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -117 Turn is: 108
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -120 Turn is: 109
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -119 Turn is: 110
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -118 Turn is: 111
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -117 Turn is: 112
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -116 Turn is: 113
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -115 Turn is: 114
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -114 Turn is: 115
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -124 Turn is: 116
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -127 Turn is: 117
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -126 Turn is: 118
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -125 Turn is: 119
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -124 Turn is: 120
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -123 Turn is: 121
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -122 Turn is: 122
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -121 Turn is: 123
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -131 Turn is: 124
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -134 Turn is: 125
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -133 Turn is: 126
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -132 Turn is: 127
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -142 Turn is: 128
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -145 Turn is: 129
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -144 Turn is: 130
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -143 Turn is: 131
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -142 Turn is: 132
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -141 Turn is: 133
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -151 Turn is: 134
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -154 Turn is: 135
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -153 Turn is: 136
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -152 Turn is: 137
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -162 Turn is: 138
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -165 Turn is: 139
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -164 Turn is: 140
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -163 Turn is: 141
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -162 Turn is: 142
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -161 Turn is: 143
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -171 Turn is: 144
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -174 Turn is: 145
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -173 Turn is: 146
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -172 Turn is: 147
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -171 Turn is: 148
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -170 Turn is: 149
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -169 Turn is: 150
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -179 Turn is: 151
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -182 Turn is: 152
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -181 Turn is: 153
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -180 Turn is: 154
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -179 Turn is: 155
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -178 Turn is: 156
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -177 Turn is: 157
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -187 Turn is: 158
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -190 Turn is: 159
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -189 Turn is: 160
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -188 Turn is: 161
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -187 Turn is: 162
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -186 Turn is: 163
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -185 Turn is: 164
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -195 Turn is: 165
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -198 Turn is: 166
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -197 Turn is: 167
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -196 Turn is: 168
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -195 Turn is: 169
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -194 Turn is: 170
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -193 Turn is: 171
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -192 Turn is: 172
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -191 Turn is: 173
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -201 Turn is: 174
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -204 Turn is: 175
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -203 Turn is: 176
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -202 Turn is: 177
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -201 Turn is: 178
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -200 Turn is: 179
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -199 Turn is: 180
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -209 Turn is: 181
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -212 Turn is: 182
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -211 Turn is: 183
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -221 Turn is: 184
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -224 Turn is: 185
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -223 Turn is: 186
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -222 Turn is: 187
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -221 Turn is: 188
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -231 Turn is: 189
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -234 Turn is: 190
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -233 Turn is: 191
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -232 Turn is: 192
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -231 Turn is: 193
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -230 Turn is: 194
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -240 Turn is: 195
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -243 Turn is: 196
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -242 Turn is: 197
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -241 Turn is: 198
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -240 Turn is: 199
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -239 Turn is: 200
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -238 Turn is: 201
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -248 Turn is: 202
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -251 Turn is: 203
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -250 Turn is: 204
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -249 Turn is: 205
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -259 Turn is: 206
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -262 Turn is: 207
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -261 Turn is: 208
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -260 Turn is: 209
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -259 Turn is: 210
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -258 Turn is: 211
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -268 Turn is: 212
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -271 Turn is: 213
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -270 Turn is: 214
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -280 Turn is: 215
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -283 Turn is: 216
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -282 Turn is: 217
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -281 Turn is: 218
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -280 Turn is: 219
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -279 Turn is: 220
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -278 Turn is: 221
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -288 Turn is: 222
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -291 Turn is: 223
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -290 Turn is: 224
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -289 Turn is: 225
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -288 Turn is: 226
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -287 Turn is: 227
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -297 Turn is: 228
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -300 Turn is: 229
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -299 Turn is: 230
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -298 Turn is: 231
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -297 Turn is: 232
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -296 Turn is: 233
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -306 Turn is: 234
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -309 Turn is: 235
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -308 Turn is: 236
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -307 Turn is: 237
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -306 Turn is: 238
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -305 Turn is: 239
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -304 Turn is: 240
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -303 Turn is: 241
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -302 Turn is: 242
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -301 Turn is: 243
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -311 Turn is: 244
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -314 Turn is: 245
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -313 Turn is: 246
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -312 Turn is: 247
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -311 Turn is: 248
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -310 Turn is: 249
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -309 Turn is: 250
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -308 Turn is: 251
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -318 Turn is: 252
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -321 Turn is: 253
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -320 Turn is: 254
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -319 Turn is: 255
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -318 Turn is: 256
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -317 Turn is: 257
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -327 Turn is: 258
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -330 Turn is: 259
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -329 Turn is: 260
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -328 Turn is: 261
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -327 Turn is: 262
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -337 Turn is: 263
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -340 Turn is: 264
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -339 Turn is: 265
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -338 Turn is: 266
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -348 Turn is: 267
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -351 Turn is: 268
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -350 Turn is: 269
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -349 Turn is: 270
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -348 Turn is: 271
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -358 Turn is: 272
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -361 Turn is: 273
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -360 Turn is: 274
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -359 Turn is: 275
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -369 Turn is: 276
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -372 Turn is: 277
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -371 Turn is: 278
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -381 Turn is: 279
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -384 Turn is: 280
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -383 Turn is: 281
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -382 Turn is: 282
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -381 Turn is: 283
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -391 Turn is: 284
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -394 Turn is: 285
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -393 Turn is: 286
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -403 Turn is: 287
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -406 Turn is: 288
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -405 Turn is: 289
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -404 Turn is: 290
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -403 Turn is: 291
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -413 Turn is: 292
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -416 Turn is: 293
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -415 Turn is: 294
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -414 Turn is: 295
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -413 Turn is: 296
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -412 Turn is: 297
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -422 Turn is: 298
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -425 Turn is: 299
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -424 Turn is: 300
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -423 Turn is: 301
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -422 Turn is: 302
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -421 Turn is: 303
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -431 Turn is: 304
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -434 Turn is: 305
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -433 Turn is: 306
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -432 Turn is: 307
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -442 Turn is: 308
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -445 Turn is: 309
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -444 Turn is: 310
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -443 Turn is: 311
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -453 Turn is: 312
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -456 Turn is: 313
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -455 Turn is: 314
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -454 Turn is: 315
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -453 Turn is: 316
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -452 Turn is: 317
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -462 Turn is: 318
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -465 Turn is: 319
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -464 Turn is: 320
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -463 Turn is: 321
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# ...
# Decision based on new data: Repair, Score is: -1610 Turn is: 846
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1613 Turn is: 847
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1616 Turn is: 848
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1619 Turn is: 849
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1618 Turn is: 850
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1617 Turn is: 851
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1627 Turn is: 852
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1630 Turn is: 853
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1633 Turn is: 854
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1636 Turn is: 855
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1646 Turn is: 856
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1649 Turn is: 857
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1648 Turn is: 858
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1647 Turn is: 859
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1646 Turn is: 860
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1656 Turn is: 861
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1659 Turn is: 862
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1662 Turn is: 863
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1661 Turn is: 864
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1664 Turn is: 865
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1667 Turn is: 866
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1670 Turn is: 867
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1673 Turn is: 868
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1676 Turn is: 869
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1679 Turn is: 870
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1678 Turn is: 871
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1681 Turn is: 872
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1684 Turn is: 873
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1687 Turn is: 874
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1690 Turn is: 875
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1700 Turn is: 876
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1703 Turn is: 877
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1706 Turn is: 878
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1709 Turn is: 879
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1712 Turn is: 880
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1715 Turn is: 881
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1718 Turn is: 882
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1728 Turn is: 883
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1731 Turn is: 884
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1730 Turn is: 885
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1729 Turn is: 886
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1732 Turn is: 887
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1735 Turn is: 888
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1738 Turn is: 889
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1741 Turn is: 890
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1744 Turn is: 891
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1743 Turn is: 892
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1746 Turn is: 893
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1749 Turn is: 894
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1752 Turn is: 895
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1751 Turn is: 896
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1754 Turn is: 897
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1757 Turn is: 898
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1760 Turn is: 899
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1763 Turn is: 900
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1766 Turn is: 901
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1769 Turn is: 902
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1768 Turn is: 903
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1771 Turn is: 904
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1770 Turn is: 905
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1773 Turn is: 906
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1772 Turn is: 907
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1782 Turn is: 908
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1785 Turn is: 909
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1784 Turn is: 910
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1787 Turn is: 911
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1790 Turn is: 912
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1793 Turn is: 913
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1792 Turn is: 914
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1791 Turn is: 915
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1794 Turn is: 916
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1797 Turn is: 917
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1800 Turn is: 918
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1803 Turn is: 919
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1806 Turn is: 920
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1809 Turn is: 921
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1812 Turn is: 922
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1815 Turn is: 923
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1818 Turn is: 924
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1821 Turn is: 925
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1824 Turn is: 926
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1827 Turn is: 927
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1830 Turn is: 928
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1833 Turn is: 929
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1836 Turn is: 930
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1835 Turn is: 931
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1838 Turn is: 932
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1841 Turn is: 933
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1844 Turn is: 934
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1843 Turn is: 935
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1846 Turn is: 936
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1849 Turn is: 937
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1852 Turn is: 938
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1855 Turn is: 939
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1858 Turn is: 940
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1861 Turn is: 941
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1864 Turn is: 942
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1863 Turn is: 943
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1862 Turn is: 944
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1872 Turn is: 945
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1875 Turn is: 946
# False
# Requesting URL: http://10.68.195.110:8000/well/drill/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Drill, Score is: -1874 Turn is: 947
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1877 Turn is: 948
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1880 Turn is: 949
# True
# Requesting URL: http://10.68.195.110:8000/well/repair/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Decision based on new data: Repair, Score is: -1883 Turn is: 950
# Ending URL: http://10.68.195.110:8000/well/end/g0L8SWwgXSZKfRM_5Ldk_uzWoLE
# Ended well with session ID: g0L8SWwgXSZKfRM_5Ldk_uzWoLE
